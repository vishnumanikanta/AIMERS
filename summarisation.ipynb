# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("summarization", model="Falconsai/text_summarization")
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.49k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/2.20k [00:00<?, ?B/s]

# %%
from transformers import pipeline

summarizer = pipeline("summarization", model="Falconsai/text_summarization")

ARTICLE = """

Computer Science and Engineering (CSE) is a dynamic and rapidly evolving field that blends principles of computer science with electrical engineering to design, develop, and analyze computer systems and their applications. Here is a comprehensive description:

Overview
Computer Science and Engineering (CSE) is an interdisciplinary domain that integrates aspects of both computer science and electrical engineering. It encompasses the design, development, and maintenance of software and hardware systems, providing the foundational knowledge and practical skills necessary to innovate and solve complex technological problems.

Key Areas of Study
Computer Science Fundamentals:

Algorithms and Data Structures: Study of efficient ways to process and manage data.
Programming Languages: Learning various programming languages such as Python, Java, C++, and their applications.
Software Engineering: Principles and practices for designing, developing, testing, and maintaining software systems.
Theory of Computation: Understanding the mathematical aspects of computing, including automata theory and complexity theory.
Engineering Principles:

Digital Logic Design: Design and analysis of digital circuits and systems.
Computer Architecture: Study of computer system organization, including processors, memory, and input/output devices.
Embedded Systems: Design and development of embedded systems, which are specialized computing systems that perform dedicated functions.
VLSI Design: Principles of designing very large-scale integration circuits.
Specialized Topics:

Artificial Intelligence and Machine Learning: Developing systems that can learn and adapt.
Cybersecurity: Protecting systems and networks from digital attacks.
Networking: Designing and managing networks, including internet architecture and protocols.
Human-Computer Interaction: Designing user-friendly interfaces and improving user experience.
Skills Developed
Problem-Solving: Ability to tackle complex problems using computational methods.
Analytical Thinking: Analyzing systems and algorithms to improve efficiency and performance.
Technical Proficiency: Proficiency in coding, software development, and hardware design.
Project Management: Managing technology projects from conception through to implementation.
Applications
Computer Science and Engineering professionals work in diverse industries, including:

Technology Companies: Developing software, hardware, and innovative tech solutions.
Finance: Creating algorithms for trading, risk management, and financial analysis.
Healthcare: Developing medical software, health informatics, and biomedical devices.
Automotive: Innovating in areas such as autonomous vehicles and automotive software.
Telecommunications: Enhancing communication technologies and networks.
Educational Path
A typical educational path in CSE includes:

Undergraduate Degree (B.Sc. or B.Eng.): Foundational courses in computer science, mathematics, and engineering.
Graduate Degree (M.Sc. or M.Eng.): Advanced topics, research opportunities, and specialized courses.
Doctoral Degree (Ph.D.): In-depth research, contributing new knowledge to the field.
"""
print(summarizer(ARTICLE, max_length=300, min_length=30, do_sample=False))
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (595 > 512). Running this sequence through the model will result in indexing errors
# [{'summary_text': 'Computer Science and Engineering (CSE) is a dynamic and rapidly evolving field that blends principles of computer science and electrical engineering to design, develop, and analyze computer systems and their applications . It encompasses the design, development, and maintenance of software and hardware systems, providing the foundational knowledge and practical skills necessary to innovate and solve complex technological problems . Computer Science Fundamentals: Algorithms and Data Structures: Study of efficient ways to process and manage data . Programming Languages: Learning various programming languages such as Python'}]

# %%
# Install necessary libraries
# !pip install transformers ipywidgets

from transformers import pipeline
import ipywidgets as widgets
from IPython.display import display

# Initialize the summarizer pipeline
summarizer = pipeline("summarization", model="Falconsai/text_summarization")

# Define the function to perform summarization
def summarize_text(text):
    summary = summarizer(text, max_length=300, min_length=30, do_sample=False)
    return summary[0]['summary_text']

# Create the text area widget for input
text_area = widgets.Textarea(
    value='',
    placeholder='Enter text here...',
    description='Input Text:',
    layout=widgets.Layout(width='100%', height='200px')
)

# Create the button to trigger summarization
button = widgets.Button(description="Summarize")

# Create the output area for the summary
output = widgets.Output()

# Define the function to handle button click
def on_button_click(b):
    with output:
        output.clear_output()
        summary = summarize_text(text_area.value)
        print("Summary:", summary)

# Attach the button click event to the handler function
button.on_click(on_button_click)

# Display the widgets
display(text_area, button, output)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 6.2 MB/s eta 0:00:00
# ...
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/1.49k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/242M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/2.32k [00:00<?, ?B/s]
# spiece.model:   0%|          | 0.00/792k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/2.42M [00:00<?, ?B/s]
# ...

# %%
# Install necessary libraries
# !pip install transformers gradio

from transformers import pipeline
import gradio as gr

# Initialize the summarizer pipeline
summarizer = pipeline("summarization", model="Falconsai/text_summarization")

# Define the function to perform summarization
def summarize_text(text):
    summary = summarizer(text, max_length=300, min_length=30, do_sample=False)
    return summary[0]['summary_text']

# Create the Gradio interface
iface = gr.Interface(
    fn=summarize_text,
    inputs=gr.components.Textbox(lines=10, placeholder="Enter text here..."),
    outputs=gr.components.Textbox(),
    title="Text Summarization Tool",
    description="Enter the text you want to summarize in the text area below, then click 'Submit' to get a concise summary.",
    theme="compact"
)

# Launch the interface
iface.launch()
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/gradio/blocks.py:983: UserWarning: Cannot load compact. Caught Exception: 404 Client Error: Not Found for url: https://huggingface.co/api/spaces/compact (Request ID: Root=1-667eee9e-56eb33261d0ba2900f480a87;c05849b5-913d-4767-953e-4f5245329c66)
#
# Sorry, we can't find the page you are looking for.
#   warnings.warn(f"Cannot load {theme}. Caught Exception: {str(e)}")
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://c8b155fa7873f892c7.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# ...
